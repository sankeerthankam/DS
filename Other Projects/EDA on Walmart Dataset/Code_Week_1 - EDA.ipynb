# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
# Read train, stores and features data
test = pd.read_csv('data/test.csv')
stores = pd.read_csv('data/stores.csv')
features = pd.read_csv('data/features.csv')
train = pd.read_csv('data/train.csv')
sampleSubmission = pd.read_csv('data/sampleSubmission.csv')

# %%
# Percentage of 'test' data
((test.count()[1])/((test.count()[1])+(train.count()[1])))*100
# Out:
# 21.441802047578051

# %% [markdown]
# #### Exploring test, stores and features data

# %%
test.head()
# Out:
#    Store  Dept        Date  IsHoliday
# 0      1     1  2012-11-02      False
# 1      1     1  2012-11-09      False
# 2      1     1  2012-11-16      False
# 3      1     1  2012-11-23       True
# 4      1     1  2012-11-30      False

# %%
stores.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %% [markdown]
# #### Merging data from 'train' and 'stores'

# %%
sample1 = pd.merge(train, stores)

# %%
sample1.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size
# 0      1     1  2010-02-05      24924.50      False    A  151315
# 1      1     1  2010-02-12      46039.49       True    A  151315
# 2      1     1  2010-02-19      41595.55      False    A  151315
# 3      1     1  2010-02-26      19403.54      False    A  151315
# 4      1     1  2010-03-05      21827.90      False    A  151315

# %%
sample2 = pd.merge(sample1, features, how='left', left_on=['Store', 'Date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-3895511b2945> in <module>()
# ----> 1 sample2 = pd.merge(sample1, features, how='left', left_on=['Store', 'Date'])
#
# C:\Users\Nishu\Anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      51                          right_on=right_on, left_index=left_index,
#      52                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 53                          copy=copy, indicator=indicator)
#      54     return op.get_result()
#      55
#
# C:\Users\Nishu\Anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     551             warnings.warn(msg, UserWarning)
#     552
# --> 553         self._validate_specification()
#     554
#     555         # note this function has side effects
#
# C:\Users\Nishu\Anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in _validate_specification(self)
#     950                                      'of levels in the index of "left"')
#     951                 self.left_on = [None] * n
# --> 952         if len(self.right_on) != len(self.left_on):
#     953             raise ValueError("len(right_on) must equal len(left_on)")
#     954
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# #### Unable to fix the error. Hence, concatinating two columns in 'features' & 'sample1' and merging data

# %%
# Concatenating 'store' and 'date' columns in 'features' dataframe
features['sd-concat'] = features['Store'].map(str)+'-'+features['Date'].map(str)

# %%
features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False
#
#       sd-concat
# 0  1-2010-02-05
# 1  1-2010-02-12
# 2  1-2010-02-19
# 3  1-2010-02-26
# 4  1-2010-03-05

# %%
# Concatenating 'store' and 'date' columns in 'features' dataframe
sample1['sd-concat'] = sample1['Store'].map(str)+'-'+sample1['Date'].map(str)

# %%
sample1.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size     sd-concat
# 0      1     1  2010-02-05      24924.50      False    A  151315  1-2010-02-05
# 1      1     1  2010-02-12      46039.49       True    A  151315  1-2010-02-12
# 2      1     1  2010-02-19      41595.55      False    A  151315  1-2010-02-19
# 3      1     1  2010-02-26      19403.54      False    A  151315  1-2010-02-26
# 4      1     1  2010-03-05      21827.90      False    A  151315  1-2010-03-05

# %% [markdown]
# #### Merging all the data into one dataframe

# %%
sample2 = pd.merge(sample1, features)

# %%
sample2
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size  \
# 0           1     1  2010-02-05      24924.50      False    A  151315
# 1           1     2  2010-02-05      50605.27      False    A  151315
# 2           1     3  2010-02-05      13740.12      False    A  151315
# 3           1     4  2010-02-05      39954.04      False    A  151315
# 4           1     5  2010-02-05      32229.38      False    A  151315
# 5           1     6  2010-02-05       5749.03      False    A  151315
# 6           1     7  2010-02-05      21084.08      False    A  151315
# 7           1     8  2010-02-05      40129.01      False    A  151315
# 8           1     9  2010-02-05      16930.99      False    A  151315
# 9           1    10  2010-02-05      30721.50      False    A  151315
# 10          1    11  2010-02-05      24213.18      False    A  151315
# 11          1    12  2010-02-05       8449.54      False    A  151315
# 12          1    13  2010-02-05      41969.29      False    A  151315
# 13          1    14  2010-02-05      19466.91      False    A  151315
# 14          1    16  2010-02-05      10217.55      False    A  151315
# 15          1    17  2010-02-05      13223.76      False    A  151315
# 16          1    18  2010-02-05       4729.50      False    A  151315
# 17          1    19  2010-02-05       1947.05      False    A  151315
# 18          1    20  2010-02-05       5034.10      False    A  151315
# 19          1    21  2010-02-05       8907.63      False    A  151315
# 20          1    22  2010-02-05      13623.98      False    A  151315
# 21          1    23  2010-02-05      24146.49      False    A  151315
# 22          1    24  2010-02-05       8272.90      False    A  151315
# 23          1    25  2010-02-05      11609.50      False    A  151315
# 24          1    26  2010-02-05      11737.12      False    A  151315
# 25          1    27  2010-02-05       2293.00      False    A  151315
# 26          1    28  2010-02-05       1085.29      False    A  151315
# 27          1    29  2010-02-05       7024.95      False    A  151315
# 28          1    30  2010-02-05       5491.00      False    A  151315
# 29          1    31  2010-02-05       3455.92      False    A  151315
# ...       ...   ...         ...           ...        ...  ...     ...
# 421540     45    41  2012-10-26       1954.67      False    B  118221
# 421541     45    42  2012-10-26       4894.78      False    B  118221
# 421542     45    44  2012-10-26       3144.09      False    B  118221
# 421543     45    46  2012-10-26      13329.25      False    B  118221
# 421544     45    52  2012-10-26       1104.16      False    B  118221
# 421545     45    54  2012-10-26         23.92      False    B  118221
# 421546     45    55  2012-10-26       3458.17      False    B  118221
# 421547     45    56  2012-10-26        937.72      False    B  118221
# 421548     45    58  2012-10-26        275.00      False    B  118221
# 421549     45    59  2012-10-26        191.98      False    B  118221
# 421550     45    60  2012-10-26        117.00      False    B  118221
# 421551     45    67  2012-10-26       5772.09      False    B  118221
# 421552     45    71  2012-10-26       2789.38      False    B  118221
# 421553     45    72  2012-10-26      33366.60      False    B  118221
# 421554     45    74  2012-10-26       9814.88      False    B  118221
# 421555     45    79  2012-10-26      14618.60      False    B  118221
# 115048        76.06       3.804     212.02     851.73       2.06      10.88
# 115049        76.06       3.804     212.02     851.73       2.06      10.88
# 115050        76.06       3.804     212.02     851.73       2.06      10.88
# 115051        76.06       3.804     212.02     851.73       2.06      10.88
# 115052        76.06       3.804     212.02     851.73       2.06      10.88
# 115053        76.06       3.804     212.02     851.73       2.06      10.88
# 115054        76.06       3.804     212.02     851.73       2.06      10.88
# 115055        76.06       3.804     212.02     851.73       2.06      10.88
# 115056        76.06       3.804     212.02     851.73       2.06      10.88
# 115057        76.06       3.804     212.02     851.73       2.06      10.88
# 115058        76.06       3.804     212.02     851.73       2.06      10.88
# 115059        76.06       3.804     212.02     851.73       2.06      10.88
# 115060        76.06       3.804     212.02     851.73       2.06      10.88
# 115061        76.06       3.804     212.02     851.73       2.06      10.88
# 115062        76.06       3.804     212.02     851.73       2.06      10.88
# 115063        76.06       3.804     212.02     851.73       2.06      10.88
#
#         MarkDown5         CPI  Unemployment
# 0         2737.42  223.462779         6.573
# 1         2737.42  223.462779         6.573
# 2         2737.42  223.462779         6.573
# 3         2737.42  223.462779         6.573
# 4         2737.42  223.462779         6.573
# 5         2737.42  223.462779         6.573
# 6         2737.42  223.462779         6.573
# 7         2737.42  223.462779         6.573
# 8         2737.42  223.462779         6.573
# 9         2737.42  223.462779         6.573
# 10        2737.42  223.462779         6.573
# 11        2737.42  223.462779         6.573
# 12        2737.42  223.462779         6.573
# 13        2737.42  223.462779         6.573
# 14        2737.42  223.462779         6.573
# 15        2737.42  223.462779         6.573
# 16        2737.42  223.462779         6.573
# 17        2737.42  223.462779         6.573
# 18        2737.42  223.462779         6.573
# 19        2737.42  223.462779         6.573
# 20        2737.42  223.462779         6.573
# 21        2737.42  223.462779         6.573
# 22        2737.42  223.462779         6.573
# 23        2737.42  223.462779         6.573
# 24        2737.42  223.462779         6.573
# 25        2737.42  223.462779         6.573
# 26        2737.42  223.462779         6.573
# 27        2737.42  223.462779         6.573
# 28        2737.42  223.462779         6.573
# 29        2737.42  223.462779         6.573
# ...           ...         ...           ...
# 115034    1864.57         NaN           NaN
# 115035    1864.57         NaN           NaN
# 115036    1864.57         NaN           NaN
# 115037    1864.57         NaN           NaN
# 115038    1864.57         NaN           NaN
# 115039    1864.57         NaN           NaN
# 115040    1864.57         NaN           NaN
# 115041    1864.57         NaN           NaN
# 115042    1864.57         NaN           NaN
# 115043    1864.57         NaN           NaN
# 115044    1864.57         NaN           NaN
# 115045    1864.57         NaN           NaN
# 115046    1864.57         NaN           NaN
# 115047    1864.57         NaN           NaN
# 115048    1864.57         NaN           NaN
# 115049    1864.57         NaN           NaN
# 115050    1864.57         NaN           NaN
# 115051    1864.57         NaN           NaN
# 115052    1864.57         NaN           NaN
# 115053    1864.57         NaN           NaN
# 115054    1864.57         NaN           NaN
# 115055    1864.57         NaN           NaN
# 115056    1864.57         NaN           NaN
# 115057    1864.57         NaN           NaN
# 115058    1864.57         NaN           NaN
# 115059    1864.57         NaN           NaN
# 115060    1864.57         NaN           NaN
# 115061    1864.57         NaN           NaN
# 115062    1864.57         NaN           NaN
# 115063    1864.57         NaN           NaN
#
# [115064 rows x 16 columns]

# %% [markdown]
# ### sample2 (train data); sample4 (test data)

# %% [markdown]
# Date is string in 'test'

# %%
df_train = sample2.copy(deep=True)
df_test = sample4.copy(deep=True)

# %%
df_train['Just_Date'] = pd.to_datetime(df_train['Date'], errors='coerce')

# %%
type(df_train['Just_Date'][1])
# Out:
# pandas._libs.tslib.Timestamp

# %%
df_train['Just_Date'] = pd.to_datetime(df_train['Date'], format = '%Y%m%d %H:%M:%S.%f')

# %%
df_train['Just_Date'][1]
# Out:
# Timestamp('2010-02-05 00:00:00')

# %%
df_train['Date'] = datetime.strptime(df_train['Just_Date'], "%d%m%Y")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-78b7d7055aac> in <module>()
# ----> 1 df_train['Date'] = datetime.strptime(df_train['Just_Date'], "%d%m%Y")
#
# TypeError: strptime() argument 1 must be str, not Series

# %%
df_train['New_Date'] = df_train['Just_Date'].apply(lambda x: datetime.strptime(x, "%d%m%Y"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-2c861cc7ec23> in <module>()
# ----> 1 df_train['New_Date'] = df_train['Just_Date'].apply(lambda x: datetime.strptime(x, "%Y%m%d"))
#
# C:\Users\Nishu\Anaconda3\Lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2353             else:
#    2354                 values = self.asobject
# -> 2355                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2356
#    2357         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\src\inference.pyx in pandas._libs.lib.map_infer (pandas\_libs\lib.c:66440)()
#
# <ipython-input-52-2c861cc7ec23> in <lambda>(x)
# ----> 1 df_train['New_Date'] = df_train['Just_Date'].apply(lambda x: datetime.strptime(x, "%Y%m%d"))
#
# TypeError: strptime() argument 1 must be str, not Timestamp

# %%
new_train = sample2.copy(deep=True)

# %%
new_train.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size  \
# 0      1     1  2010-02-05      24924.50      False    A  151315
# 1      1     2  2010-02-05      50605.27      False    A  151315
# 2      1     3  2010-02-05      13740.12      False    A  151315
# 3      1     4  2010-02-05      39954.04      False    A  151315
# 4      1     5  2010-02-05      32229.38      False    A  151315
#
#       sd-concat  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0  1-2010-02-05        42.31       2.572        NaN        NaN        NaN
# 1  1-2010-02-05        42.31       2.572        NaN        NaN        NaN
# 2  1-2010-02-05        42.31       2.572        NaN        NaN        NaN
# 3  1-2010-02-05        42.31       2.572        NaN        NaN        NaN
# 4  1-2010-02-05        42.31       2.572        NaN        NaN        NaN
#
#    MarkDown4  MarkDown5         CPI  Unemployment
# 0        NaN        NaN  211.096358         8.106
# 1        NaN        NaN  211.096358         8.106
# 2        NaN        NaN  211.096358         8.106
# 3        NaN        NaN  211.096358         8.106
# 4        NaN        NaN  211.096358         8.106

# %%
df_train['New_Date'] = df_train['Date'].apply(lambda x: datetime.strptime(x, "%Y-%m-%d"))

# %%
df_train['New_Date'].head()
# Out:
# 0   2010-02-05
# 1   2010-02-05
# 2   2010-02-05
# 3   2010-02-05
# 4   2010-02-05
# Name: New_Date, dtype: datetime64[ns]

# %%
from dateutil.parser import parse
a = parse(df_train['Date'][1]).date().isoformat()

# %%
type(a)
# Out:
# str

# %%
pd.to_datetime()
# Out:
# str
