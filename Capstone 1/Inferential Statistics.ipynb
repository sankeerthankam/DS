# %%
# Jupyter Notebook with Matplotlib Inline
# %matplotlib notebook

# Importing necessary modules
import pandas as pd
import numpy as np
import seaborn as sns
# import matplotlib as plt
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# Read the cleaned datasets
train = pd.read_csv("train.csv", delimiter=',')
df = pd.read_csv("train.csv", delimiter=',')
test = pd.read_csv("test.csv", delimiter=',')

# %%
train.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'personal',
#        'contact_type', 'month', 'day', 'duration', 'dcontacts', 'pdays',
#        'pcontacts', 'poutcome', 'evr', 'cpi', 'cci', 'euribor', 'employees',
#        'y'],
#       dtype='object')

# %%
# ......................................EDCF........................................

# %%
# Age

# %%
sns.set()
sns.distplot(df.age, bins = 20, color = 'orange')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# Calculating mean and standard deviation
age = df.age
age_mean, age_std = age.mean(), age.std()
n = len(age)

# ECDF 
def ecdf(data):
    n = len(data)
    x = np.sort(data)
    y = np.arange(1,n+1)/n
    return x,y

# %%
# Seeding the random number generator:
np.random.seed(10)

# Drawing random samples from random distribution
age_random_samples = np.random.normal(age_mean, age_std, size=10000)

# %%
# ECDF on temperature data and on random samples
age_x, age_y = ecdf(age)
age_random_samples_x, age_random_samples_y = ecdf(age_random_samples)

# Plotting the ECDFs for temperature and random sample 
sns.set()
_ = plt.plot(age_random_samples_x, age_random_samples_y)
_ = plt.plot(age_x, age_y, marker = '.', linestyle = 'none')
_ = plt.xlabel('Temperature')
_ = plt.ylabel('CDF')
_ = plt.legend(('Distribution', 'Empirical Data'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# Duration

# %%
sns.set()
sns.distplot(df.duration, bins = 20, color = 'green')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# duration
duration = df.duration
duration_mean, duration_std = duration.mean(), duration.std()
n = len(duration)

# Seeding the random number generator:
np.random.seed(10)

# Drawing random samples from random distribution
duration_random_samples = np.random.normal(duration_mean, duration_std, size=10000)

# ECDF on temperature data and on random samples
duration_x, duration_y = ecdf(duration)
duration_random_samples_x, duration_random_samples_y = ecdf(duration_random_samples)

# Plotting the ECDFs for temperature and random sample 
sns.set()
_ = plt.plot(duration_random_samples_x, duration_random_samples_y)
_ = plt.plot(duration_x, duration_y, marker = '.', linestyle = 'none')
_ = plt.xlabel('Duration')
_ = plt.ylabel('CDF')
_ = plt.legend(('Distribution', 'Empirical Data'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# DContacts

# %%
sns.set()
sns.distplot(df.dcontacts, bins = 20, color = 'blue')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# DContacts
dcontacts = df.dcontacts
dcontacts_mean, dcontacts_std = dcontacts.mean(), dcontacts.std()
n = len(dcontacts)

# Seeding the random number generator:
np.random.seed(10)

# Drawing random samples from random distribution
dcontacts_random_samples = np.random.normal(dcontacts_mean, dcontacts_std, size=10000)

# ECDF on temperature data and on random samples
dcontacts_x, dcontacts_y = ecdf(dcontacts)
dcontacts_random_samples_x, dcontacts_random_samples_y = ecdf(dcontacts_random_samples)

# Plotting the ECDFs for temperature and random sample 
sns.set()
_ = plt.plot(dcontacts_random_samples_x, dcontacts_random_samples_y)
_ = plt.plot(dcontacts_x, dcontacts_y, marker = '.', linestyle = 'none')
_ = plt.xlabel('DContacts')
_ = plt.ylabel('CDF')
_ = plt.legend(('Distribution', 'Empirical Data'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# PDays

# %%
sns.set()
sns.distplot(df.pdays, bins = 20, color = 'orange')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# PDays
pdays = df.pdays
pdays_mean, pdays_std = pdays.mean(), pdays.std()
n = len(pdays)

# Seeding the random number generator:
np.random.seed(10)

# Drawing random samples from random distribution
pdays_random_samples = np.random.normal(pdays_mean, pdays_std, size=10000)

# ECDF on temperature data and on random samples
pdays_x, pdays_y = ecdf(pdays)
pdays_random_samples_x, pdays_random_samples_y = ecdf(pdays_random_samples)

# Plotting the ECDFs for temperature and random sample 
sns.set()
_ = plt.plot(pdays_random_samples_x, pdays_random_samples_y)
_ = plt.plot(pdays_x, pdays_y, marker = '.', linestyle = 'none')
_ = plt.xlabel('PDays')
_ = plt.ylabel('CDF')
_ = plt.legend(('Distribution', 'Empirical Data'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# 999 means a custmer has not been contacted previously

# %%
# PContacts

# %%
sns.set()
sns.distplot(df.pcontacts, bins = 20, color = 'green')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# PContacts
pcontacts = df.pcontacts
pcontacts_mean, pcontacts_std = pcontacts.mean(), pcontacts.std()
n = len(pcontacts)

# Seeding the random number generator:
np.random.seed(10)

# Drawing random samples from random distribution
pcontacts_random_samples = np.random.normal(pcontacts_mean, pcontacts_std, size=10000)

# ECDF on temperature data and on random samples
pcontacts_x, pcontacts_y = ecdf(pcontacts)
pcontacts_random_samples_x, pcontacts_random_samples_y = ecdf(pcontacts_random_samples)

# Plotting the ECDFs for temperature and random sample 
sns.set()
_ = plt.plot(pcontacts_random_samples_x, pcontacts_random_samples_y)
_ = plt.plot(pcontacts_x, pcontacts_y, marker = '.', linestyle = 'none')
_ = plt.xlabel('PContacts')
_ = plt.ylabel('CDF')
_ = plt.legend(('Distribution', 'Empirical Data'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# EVR

# %%
sns.set()
sns.distplot(df.evr, bins = 20, color = 'blue')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# EVR
evr = df.evr
evr_mean, evr_std = evr.mean(), evr.std()
n = len(evr)

# Seeding the random number generator:
np.random.seed(10)

# Drawing random samples from random distribution
evr_random_samples = np.random.normal(evr_mean, evr_std, size=10000)

# ECDF on temperature data and on random samples
evr_x, evr_y = ecdf(evr)
evr_random_samples_x, evr_random_samples_y = ecdf(evr_random_samples)

# Plotting the ECDFs for temperature and random sample 
sns.set()
_ = plt.plot(evr_random_samples_x, evr_random_samples_y)
_ = plt.plot(evr_x, evr_y, marker = '.', linestyle = 'none')
_ = plt.xlabel('EVR')
_ = plt.ylabel('CDF')
_ = plt.legend(('Distribution', 'Empirical Data'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# Not a continous variable. Hence ECDF is not applicable for this

# %%
# CPI

# %%
sns.set()
sns.distplot(df.cpi, bins = 20, color = 'orange')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# CPI
cpi = df.cpi
cpi_mean, cpi_std = cpi.mean(), cpi.std()
n = len(cpi)

# Seeding the random number generator:
np.random.seed(10)

# Drawing random samples from random distribution
cpi_random_samples = np.random.normal(cpi_mean, cpi_std, size=10000)

# ECDF on temperature data and on random samples
cpi_x, cpi_y = ecdf(cpi)
cpi_random_samples_x, cpi_random_samples_y = ecdf(cpi_random_samples)

# Plotting the ECDFs for temperature and random sample 
sns.set()
_ = plt.plot(cpi_random_samples_x, cpi_random_samples_y)
_ = plt.plot(cpi_x, cpi_y, marker = '.', linestyle = 'none')
_ = plt.xlabel('CPI')
_ = plt.ylabel('CDF')
_ = plt.legend(('Distribution', 'Empirical Data'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# Not a continous variable. Hence ECDF is not applicable for this

# %%
# CCI

# %%
sns.set()
sns.distplot(df.cci, bins = 20, color = 'green')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# CCI
cci = df.cci
cci_mean, cci_std = cci.mean(), cci.std()
n = len(cci)

# Seeding the random number generator:
np.random.seed(10)

# Drawing random samples from random distribution
cci_random_samples = np.random.normal(cci_mean, cci_std, size=10000)

# ECDF on temperature data and on random samples
cci_x, cci_y = ecdf(cci)
cci_random_samples_x, cci_random_samples_y = ecdf(cci_random_samples)

# Plotting the ECDFs for temperature and random sample 
sns.set()
_ = plt.plot(cci_random_samples_x, cci_random_samples_y)
_ = plt.plot(cci_x, cci_y, marker = '.', linestyle = 'none')
_ = plt.xlabel('CCI')
_ = plt.ylabel('CDF')
_ = plt.legend(('Distribution', 'Empirical Data'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# Not a continous variable. Hence ECDF is not applicable for this

# %%
# EURIBOR

# %%
sns.set()
sns.distplot(df.euribor, bins = 20, color = 'blue')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# Euribor
euribor = df.euribor
euribor_mean, euribor_std = euribor.mean(), euribor.std()
n = len(euribor)

# Seeding the random number generator:
np.random.seed(10)

# Drawing random samples from random distribution
euribor_random_samples = np.random.normal(euribor_mean, euribor_std, size=10000)

# ECDF on temperature data and on random samples
euribor_x, euribor_y = ecdf(euribor)
euribor_random_samples_x, euribor_random_samples_y = ecdf(euribor_random_samples)

# Plotting the ECDFs for temperature and random sample 
sns.set()
_ = plt.plot(euribor_random_samples_x, euribor_random_samples_y)
_ = plt.plot(euribor_x, euribor_y, marker = '.', linestyle = 'none')
_ = plt.xlabel('Euribor')
_ = plt.ylabel('CDF')
_ = plt.legend(('Distribution', 'Empirical Data'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# Not a continous variable. Hence ECDF is not applicable for this

# %%
# EMPLOYEES

# %%
sns.set()
sns.distplot(df.employees, bins = 20, color = 'orange')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# employees
employees = df.employees
employees_mean, employees_std = employees.mean(), employees.std()
n = len(employees)

# Seeding the random number generator:
np.random.seed(10)

# Drawing random samples from random distribution
employees_random_samples = np.random.normal(employees_mean, employees_std, size=10000)

# ECDF on temperature data and on random samples
employees_x, employees_y = ecdf(employees)
employees_random_samples_x, employees_random_samples_y = ecdf(employees_random_samples)

# Plotting the ECDFs for temperature and random sample 
sns.set()
_ = plt.plot(employees_random_samples_x, employees_random_samples_y)
_ = plt.plot(employees_x, employees_y, marker = '.', linestyle = 'none')
_ = plt.xlabel('Employees')
_ = plt.ylabel('CDF')
_ = plt.legend(('Distribution', 'Empirical Data'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# Not a continous variable. Hence ECDF is not applicable for this
