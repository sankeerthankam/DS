# %% [markdown]
# <h1><center>EDA on Bank Marketing Dataset</center></h1>

# %% [markdown]
# <center>https://archive.ics.uci.edu/ml/datasets/Bank+Marketing</center>

# %%
# Jupyter Notebook with Matplotlib Inline
# %matplotlib notebook

# Importing necessary modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
from sklearn.model_selection import train_test_split

# %%
# Reading the csv file.
df = pd.read_csv("bank-additional-full.csv", delimiter=';')

# %%
# Columns in the data
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
# Renaming columns
df.columns = ['age', 'job', 'marital', 'education', 'default', 'housing', 'personal', 'contact', 'month', 'day_of_week', 
              'duration', 'campaign', 'pdays', 'pcontacts', 'poutcome', 'evr', 'cpi', 'cci', 'euribor', 'employees', 'y']

# %%
# Top 5 rows of the data 
df.head()
# Out:
#    age        job  marital    education  default housing personal    contact  \
# 0   56  housemaid  married     basic.4y       no      no       no  telephone
# 1   57   services  married  high.school  unknown      no       no  telephone
# 2   37   services  married  high.school       no     yes       no  telephone
# 3   40     admin.  married     basic.6y       no      no       no  telephone
# 4   56   services  married  high.school       no      no      yes  telephone
#
#   month day_of_week ...  campaign  pdays  pcontacts     poutcome  evr     cpi  \
# 0   may         mon ...         1    999          0  nonexistent  1.1  93.994
# 1   may         mon ...         1    999          0  nonexistent  1.1  93.994
# 2   may         mon ...         1    999          0  nonexistent  1.1  93.994
# 3   may         mon ...         1    999          0  nonexistent  1.1  93.994
# 4   may         mon ...         1    999          0  nonexistent  1.1  93.994
#
#     cci  euribor  employees   y
# ...

# %%
# New columns
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'personal',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'pcontacts', 'poutcome', 'evr', 'cpi', 'cci', 'euribor', 'employees',
#        'y'],
#       dtype='object')

# %%
# Dividing the data into train and test sets
train, test = train_test_split(df, test_size=0.2)

# %%
# Shape of the training dataset
train.shape
# Out:
# (32950, 21)

# %%
# Exporting the files
out_train = 'train.csv'
train.to_csv(out_train)
out_test = 'test.csv'
test.to_csv(out_test)

# %%
# Reading newly created test and training data as train_sample and test_sample variables
train_sample = pd.read_csv("train.csv", delimiter=',') 
test_sample = pd.read_csv("test.csv", delimiter=',')

# %%
#New data set contains 22 columns as opposed to 21
train_sample.shape
# Out:
# (32950, 21)

# %%
#unnamed:0 is the extra column
train_sample.columns
# Out:
# Index(['Unnamed: 0', 'age', 'job', 'marital', 'education', 'default',
#        'housing', 'loan', 'contact', 'month', 'day_of_week', 'duration',
#        'campaign', 'pdays', 'pcontacts', 'poutcome', 'evr', 'cpi', 'cci',
#        'euribor', 'employees', 'y'],
#       dtype='object')

# %%
train_sample.head()
# Out:
#    Unnamed: 0  age           job   marital            education default  \
# 0       29169   41        admin.    single  professional.course      no
# 1       16663   55    management   married             basic.9y      no
# 2       28623   55        admin.   married          high.school      no
# 3       26979   36        admin.  divorced    university.degree      no
# 4         543   32  entrepreneur    single    university.degree      no
#
#   housing loan    contact month ... campaign  pdays  pcontacts     poutcome  \
# 0     yes  yes   cellular   apr ...        1    999          0  nonexistent
# 1     yes   no   cellular   jul ...        2    999          0  nonexistent
# 2     yes   no   cellular   apr ...        3    999          1      failure
# 3      no  yes   cellular   nov ...        2    999          0  nonexistent
# 4     yes   no  telephone   may ...        2    999          0  nonexistent
#
#    evr     cpi   cci  euribor  employees   y
# ...

# %%
#Dropping extra column inplace for test_sample
train_sample.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
# train = pd.read_csv("train.csv", delimiter=',', index_col = 0).reset_index().drop('index',axis=1)
# test = pd.read_csv("test.csv", delimiter=',', index_col = 0).reset_index().drop('index',axis=1)

# %%
train_sample.head()
# Out:
#    age           job   marital            education default housing loan  \
# 0   41        admin.    single  professional.course      no     yes  yes
# 1   55    management   married             basic.9y      no     yes   no
# 2   55        admin.   married          high.school      no     yes   no
# 3   36        admin.  divorced    university.degree      no      no  yes
# 4   32  entrepreneur    single    university.degree      no     yes   no
#
#      contact month day_of_week ...  campaign  pdays  pcontacts     poutcome  \
# 0   cellular   apr         fri ...         1    999          0  nonexistent
# 1   cellular   jul         wed ...         2    999          0  nonexistent
# 2   cellular   apr         wed ...         3    999          1      failure
# 3   cellular   nov         thu ...         2    999          0  nonexistent
# 4  telephone   may         tue ...         2    999          0  nonexistent
#
#    evr     cpi   cci  euribor  employees   y
# ...

# %%
#Dropping extra column inplace for train_sample 
test_sample.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
train_sample.head()
# Out:
#    age           job   marital            education default housing loan  \
# 0   41        admin.    single  professional.course      no     yes  yes
# 1   55    management   married             basic.9y      no     yes   no
# 2   55        admin.   married          high.school      no     yes   no
# 3   36        admin.  divorced    university.degree      no      no  yes
# 4   32  entrepreneur    single    university.degree      no     yes   no
#
#      contact month day_of_week ...  campaign  pdays  pcontacts     poutcome  \
# 0   cellular   apr         fri ...         1    999          0  nonexistent
# 1   cellular   jul         wed ...         2    999          0  nonexistent
# 2   cellular   apr         wed ...         3    999          1      failure
# 3   cellular   nov         thu ...         2    999          0  nonexistent
# 4  telephone   may         tue ...         2    999          0  nonexistent
#
#    evr     cpi   cci  euribor  employees   y
# ...

# %%
#Export the newly cleaned datasets 
out_train = 'train.csv'
train_sample.to_csv(out_train)
out_test = 'test.csv'
test_sample.to_csv(out_test)

# %% [markdown]
# Data split into Train and Test. Dropped unnecessary columns.
# Loading the new files.

# %%
# Read the cleaned datasets
train = pd.read_csv("train.csv", delimiter=',') 
test = pd.read_csv("test.csv", delimiter=',')

# %%
# Shape of the Training dataset 
train.shape
# Out:
# (32950, 21)

# %%
# Shape of test dataset
test.shape
# Out:
# (8238, 21)

# %%
# Change the column names
train.columns = ['age', 'job', 'marital', 'education', 'default', 'housing', 'personal',
       'contact_type', 'month', 'day', 'duration', 'dcontacts', 'pdays',
       'pcontacts', 'poutcome', 'evr', 'cpi', 'cci', 'euribor', 'employees',
       'y']

# %%
# Counts of each outcome
train.groupby('y')['y'].count()
# Out:
# y
# no     29208
# yes     3742
# Name: y, dtype: int64

# %%
train['y'].value_counts()
# Out:
# no     29208
# yes     3742
# Name: y, dtype: int64

# %% [markdown]
# <h2><u> EDA on Categorical Variables </u></h2>

# %% [markdown]
# <h3> 'job' variable </h3>

# %%
pd.crosstab(train.job, train.y)
# Out:
# y                no   yes
# job
# admin.         7290  1066
# blue-collar    6846   506
# entrepreneur   1095   102
# housemaid       741    89
# management     2073   267
# retired        1027   355
# self-employed  1023   125
# services       2902   259
# student         492   232
# technician     4784   590
# unemployed      694   119
# unknown         241    32

# %%
# Countplot for job vs 'y'
sns.countplot(y="job", hue="y", data=train, palette="RdBu")
# palette = (None, "muted", "RdBu", "Blues_d", "husl" )
# https://seaborn.pydata.org/generated/seaborn.color_palette.html#seaborn.color_palette
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# Since the number of entries for each category in a categorical variable is quite varying, percentage of each category would
# give a better look at the data (Hence we normalize the index in 'crosstab')
# The proportions shown in the output are row proportions

# %%
# Normalizing index because we are analyzing @ "category-level"
#1-0 Encoding Creating dummy varz (https://www.youtube.com/watch?v=0s_1IsROgDc)
pd.crosstab(train.job, train.y, normalize='index')
# Out:
# y                    no       yes
# job
# admin.         0.872427  0.127573
# blue-collar    0.931175  0.068825
# entrepreneur   0.914787  0.085213
# housemaid      0.892771  0.107229
# management     0.885897  0.114103
# retired        0.743126  0.256874
# self-employed  0.891115  0.108885
# services       0.918064  0.081936
# student        0.679558  0.320442
# technician     0.890212  0.109788
# unemployed     0.853629  0.146371
# unknown        0.882784  0.117216

# %%
pd.crosstab(train.job, train.y, normalize='columns')
# Out:
# y                    no       yes
# job
# admin.         0.249589  0.284874
# blue-collar    0.234388  0.135222
# entrepreneur   0.037490  0.027258
# housemaid      0.025370  0.023784
# management     0.070974  0.071352
# retired        0.035162  0.094869
# self-employed  0.035025  0.033405
# services       0.099356  0.069214
# student        0.016845  0.061999
# technician     0.163791  0.157670
# unemployed     0.023761  0.031801
# unknown        0.008251  0.008552

# %% [markdown]
#  Admin category has the highest number of positive and negative responses while 'unknown' has the lowest for the both.
#  Around 64% of the people considered for this survey belong to either 'Admin', 'Blue-Collar' or 'Technician'  categories.
#  Within categories, Retired and Students had high positive response rate (25% and 32%) while blue-collars and entrepreneurs (6% and 8%) had the lowest positive response rate. At category-level, Admin and Technicians contributed the highest percentage of positive response rate.

# %% [markdown]
# ## 'Marital' variable

# %%
pd.crosstab(train.marital, train.y)
# Out:
# y            no   yes
# marital
# divorced   3262   390
# married   17940  2044
# single     7954  1298
# unknown      52    10

# %%
sns.countplot(y="marital", hue="y", data=train, palette="RdBu")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
pd.crosstab(train.marital, train.y, normalize='index')
# Out:
# y               no       yes
# marital
# divorced  0.893209  0.106791
# married   0.897718  0.102282
# single    0.859706  0.140294
# unknown   0.838710  0.161290

# %%
pd.crosstab(train.marital, train.y, normalize='columns')
# Out:
# y               no       yes
# marital
# divorced  0.111682  0.104222
# married   0.614215  0.546232
# single    0.272323  0.346873
# unknown   0.001780  0.002672

# %% [markdown]
#  Married category has the highest number of positive responses.
#  Around 60% of the people considered for this survey belong to either 'married' category.
#  Within the category, 'unknown' has the highest positive response rate.
#  At category-level, with 55% 'married' contributed the highest percentage of positive response rate.

# %% [markdown]
# ## 'Education' variable

# %%
pd.crosstab(train.education, train.y)
# Out:
# y                      no   yes
# education
# basic.4y             2974   356
# basic.6y             1672   143
# basic.9y             4474   372
# high.school          6780   855
# illiterate              9     3
# professional.course  3697   497
# university.degree    8396  1320
# unknown              1206   196

# %%
sns.countplot(y="education", hue="y", data=train, palette="RdBu")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
pd.crosstab(train.education, train.y, normalize='index')
# Out:
# y                          no       yes
# education
# basic.4y             0.893093  0.106907
# basic.6y             0.921212  0.078788
# basic.9y             0.923236  0.076764
# high.school          0.888016  0.111984
# illiterate           0.750000  0.250000
# professional.course  0.881497  0.118503
# university.degree    0.864142  0.135858
# unknown              0.860200  0.139800

# %%
pd.crosstab(train.education, train.y, normalize='columns')
# Out:
# y                          no       yes
# education
# basic.4y             0.101821  0.095136
# basic.6y             0.057245  0.038215
# basic.9y             0.153177  0.099412
# high.school          0.232128  0.228487
# illiterate           0.000308  0.000802
# professional.course  0.126575  0.132817
# university.degree    0.287455  0.352753
# unknown              0.041290  0.052378

# %% [markdown]
#  Around 5% of the datapoints has an education level of either 'illiterate' or 'unknown'.
#  Though 'illiterate' and 'unknown' contribute to only 5% of the total datapoints, they have the highest positive response rate within categories.

# %% [markdown]
# ## 'Default' variable

# %%
pd.crosstab(train.default, train.y)
# Out:
# y           no   yes
# default
# no       22666  3381
# unknown   6539   361
# yes          3     0

# %%
sns.countplot(y="default", hue="y", data=train, palette="RdBu")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
pd.crosstab(train.default, train.y, normalize='index')
# Out:
# y              no       yes
# default
# no       0.870196  0.129804
# unknown  0.947681  0.052319
# yes      1.000000  0.000000

# %%
pd.crosstab(train.default, train.y, normalize='columns')
# Out:
# y              no       yes
# default
# no       0.776020  0.903528
# unknown  0.223877  0.096472
# yes      0.000103  0.000000

# %% [markdown]
#  Most number of people who were approached do not have a default.
#  Almost 20% of the datapoints are 'unknown'.
#  None of the customers with loan default have responded positively to the offer.

# %% [markdown]
# ## 'Housing' variable

# %%
pd.crosstab(train.housing, train.y)
# Out:
# y           no   yes
# housing
# no       13254  1640
# unknown    704    81
# yes      15250  2021

# %%
sns.countplot(y="housing", hue="y", data=train, palette="RdBu")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
pd.crosstab(train.housing, train.y, normalize='index')
# Out:
# y              no       yes
# housing
# no       0.889889  0.110111
# unknown  0.896815  0.103185
# yes      0.882983  0.117017

# %%
pd.crosstab(train.housing, train.y, normalize='columns')
# Out:
# y              no       yes
# housing
# no       0.453780  0.438268
# unknown  0.024103  0.021646
# yes      0.522117  0.540086

# %% [markdown]
# Two major classes (people with/without housing loan) are almost equally distributed.
# Customers with no housing loan have less positive response rate compared to the ones with housing loan.

# %% [markdown]
# # 'Personal' variable

# %%
pd.crosstab(train.personal, train.y)
# Out:
# y            no   yes
# personal
# no        24044  3110
# unknown     704    81
# yes        4460   551

# %%
sns.countplot(y="personal", hue="y", data=train, palette="RdBu")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
pd.crosstab(train.personal, train.y, normalize='index')
# Out:
# y               no       yes
# personal
# no        0.885468  0.114532
# unknown   0.896815  0.103185
# yes       0.890042  0.109958

# %%
pd.crosstab(train.personal, train.y, normalize='columns')
# Out:
# y               no       yes
# personal
# no        0.823199  0.831106
# unknown   0.024103  0.021646
# yes       0.152698  0.147247

# %% [markdown]
#  Around 82% of datapoints do not have a personal loan on them.
#  Within each category, each of them contributed to the same percentage for a positive response.

# %% [markdown]
# # 'Contact_type' variable

# %%
pd.crosstab(train.contact_type, train.y)
# Out:
# y                no   yes
# contact_type
# cellular      17784  3115
# telephone     11424   627

# %%
sns.countplot(y="contact_type", hue="y", data=train, palette="RdBu")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
pd.crosstab(train.contact_type, train.y, normalize='index')
# Out:
# y                   no       yes
# contact_type
# cellular      0.850950  0.149050
# telephone     0.947971  0.052029

# %%
pd.crosstab(train.contact_type, train.y, normalize='columns')
# Out:
# y                   no       yes
# contact_type
# cellular      0.608874  0.832443
# telephone     0.391126  0.167557

# %% [markdown]
#  Customers with cellular phone are more likely to respond positively.
#  At category-level, customers with telephone contributed least to the positive response rate.

# %% [markdown]
# # 'Month' variable

# %%
pd.crosstab(train.month, train.y)
# Out:
# y         no  yes
# month
# apr     1681  428
# aug     4433  530
# dec       75   69
# jul     5191  532
# jun     3812  458
# mar      211  218
# may    10302  725
# nov     2930  319
# oct      329  253
# sep      244  210

# %%
sns.countplot(y="month", hue="y", data=train, palette="RdBu")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
pd.crosstab(train.month, train.y, normalize='index')
# Out:
# y            no       yes
# month
# apr    0.797060  0.202940
# aug    0.893210  0.106790
# dec    0.520833  0.479167
# jul    0.907042  0.092958
# jun    0.892740  0.107260
# mar    0.491841  0.508159
# may    0.934252  0.065748
# nov    0.901816  0.098184
# oct    0.565292  0.434708
# sep    0.537445  0.462555

# %%
pd.crosstab(train.month, train.y, normalize='columns')
# Out:
# y            no       yes
# month
# apr    0.057553  0.114377
# aug    0.151773  0.141635
# dec    0.002568  0.018439
# jul    0.177725  0.142170
# jun    0.130512  0.122394
# mar    0.007224  0.058258
# may    0.352712  0.193747
# nov    0.100315  0.085249
# oct    0.011264  0.067611
# sep    0.008354  0.056120

# %% [markdown]
#  Most customers were contacted during the second quarter of the calender year.
#  Highest positive response percentage was recorded in March, September and December
#  Highest percentage of positive response was recorded in the final quarter while the lowest percentage was recorded in 'November' which also fall in the final quarter of the year.

# %% [markdown]
# # 'Day' variable

# %% [markdown]
# pd.crosstab(train.day, train.y)

# %%
sns.countplot(y="day", hue="y", data=train, palette="RdBu")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
pd.crosstab(train.day, train.y, normalize='index')
# Out:
# y          no       yes
# day
# fri  0.889405  0.110595
# mon  0.899162  0.100838
# thu  0.876035  0.123965
# tue  0.882904  0.117096
# wed  0.884810  0.115190

# %%
pd.crosstab(train.day, train.y, normalize='columns')
# Out:
# y          no       yes
# day
# fri  0.189982  0.184393
# mon  0.209429  0.183324
# thu  0.206382  0.227953
# tue  0.196967  0.203902
# wed  0.197240  0.200428

# %% [markdown]
#  All classes are almost equally distributed both in terms of numbers and percentage.

# %% [markdown]
# # 'Poutcome' variable

# %%
pd.crosstab(train.poutcome, train.y)
# Out:
# y               no   yes
# poutcome
# failure       2902   483
# nonexistent  25936  2546
# success        370   713

# %%
sns.countplot(y="poutcome", hue="y", data=train, palette="RdBu")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
pd.crosstab(train.poutcome, train.y, normalize='index')
# Out:
# y                  no       yes
# poutcome
# failure      0.857312  0.142688
# nonexistent  0.910610  0.089390
# success      0.341644  0.658356

# %%
pd.crosstab(train.poutcome, train.y, normalize='columns')
# Out:
# y                  no       yes
# poutcome
# failure      0.099356  0.129075
# nonexistent  0.887976  0.680385
# success      0.012668  0.190540

# %% [markdown]
#  Most of the customers have not been contacted for the previous campaign.
#  Of the customers who have not accepted the previous offer, only 14% of them have accepted the current offer.
#  About 65% of customers who have accepted the offer previously, have also accepted current offer.

# %% [markdown]
# # EDA with Numeric Variables

# %%
# varz = [age, duration, campaign, pdays, previous, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed]

# %%
# varz = train[['age','duration','campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']]
# #           [, duration, campaign, pdays, previous, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed]
# type(varz)

# %%
#Summary statistics of Quantitative variables
train.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.016965    258.239575      2.579211    963.076601      0.171502
# std       10.385912    260.890202      2.793047    185.428154      0.491755
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    319.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     43.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.085520       93.576952     -40.513976      3.624486   5167.189964
# ...

# %%
sns.pairplot(train, hue = "y", size = 1);
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # 'age' variable

# %%
sns.FacetGrid(train, hue = "y", size = 5).map(sns.distplot, "age").add_legend();
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
sns.boxplot(x="y", y="age", data=train)
sns.violinplot(x="y", y="age", data=train, size=6)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
#  The variance of age of the customers who have rejected the offer is lower compared to that of the customers who have
#  responded positively to the offer.
#  Even though most obervations are around early 30's, the mean has been recorded around late 30's for both the classes.
#  There are significant number of outliers for both classes. However, the outliers for 'no' are widespread.
#  Binnig the 'age' variable with respect to 'job' category might provide us better insights.

# %% [markdown]
# # 'duration' variable

# %%
sns.FacetGrid(train, hue = "y", size = 5).map(sns.distplot, "duration").add_legend();
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
sns.boxplot(x="y", y = "duration", data = train)
sns.violinplot(x="y", y="duration", data=train, size=6)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
#  The variance of 'no' class is less compared to that of 'yes' class.
#  Outliers for 'no' are widespread than the outliers of 'yes'.
#  Since the data is widespread, it's a good idea to bin them and include upper bounds.

# %% [markdown]
# # 'campaign' variable

# %%
sns.FacetGrid(train, hue = "y", size = 5).map(sns.distplot, "campaign").add_legend();
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
sns.boxplot(x="y", y = "campaign", data = train)
sns.violinplot(x="y", y="campaign", data=train, size=6)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
#  95% of the datapoints are almost equally distributed for both the classes.
#  However, the outliers are more loosely distributed for 'no' class than 'yes' class.

# %% [markdown]
# # 'pdays' variable

# %%
sns.FacetGrid(train, hue = "y", size = 5).map(sns.distplot, "pdays").add_legend();
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
sns.boxplot(x="y", y = "pdays", data = train)
sns.violinplot(x="y", y="pdays", data=train, size=6) # replace the ouliers by lower and upper bounds
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
#  Since 999 denotes that the customer has not been contacted, it looks like majority of the customers from 'no' class have not been previously contacted.
#  Same is the case for most of the customers in 'yes' class. However, a decent amount of customers have been contacted before this campaign which can be seen in the first peak of this bi-modal distribution.

# %% [markdown]
# # 'pcontacts' variable

# %%
sns.FacetGrid(train, hue = "y", size = 5).map(sns.distplot, "previous").add_legend();
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
sns.boxplot(x="y", y = "previous", data = train)
sns.violinplot(x="y", y="previous", data=train, size=6)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
#  The 'no' class has a bi-modal while 'yes' class has a tri-modal distribution.
#  There are few outliers for both classes which do not have significant affect on majority of the data.

# %% [markdown]
# # 'evr' variable

# %%
sns.FacetGrid(train, hue = "y", size = 5).map(sns.distplot, "emp.var.rate").add_legend();
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
sns.boxplot(x="y", y = "emp.var.rate", data = train)
sns.violinplot(x="y", y="emp.var.rate", data=train, size=6)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
#  Most obervations of EVR rate have been recorded between -2 and 2 for both classes.
#  However, the obervations of 'yes' class have recorded a significant amount of them with values between -4 and -2.

# %% [markdown]
# # 'cpi' variable

# %%
sns.FacetGrid(train, hue = "y", size = 5).map(sns.distplot, "cons.price.idx").add_legend();
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
sns.boxplot(x="y", y = "cons.price.idx", data = train)
sns.violinplot(x="y", y="cons.price.idx", data=train, size=6)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
#  80% of the observations have been recorded between 93 and 94.
#  However, the emans for 'no' class is close to 94 while for 'yes' class is claose to 93.

# %% [markdown]
# # 'cci' variable

# %%
sns.FacetGrid(train, hue = "y", size = 5).map(sns.distplot, "cons.conf.idx").add_legend();
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
sns.boxplot(x="y", y = "cons.conf.idx", data = train)
sns.violinplot(x="y", y="cons.conf.idx", data=train, size=6)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
#  The means for both classes are almost equal.
#  However, 'no' class has observations densely at -36 and -43 while 'yes' class has observations significantlu spread from -52 to -30 in it's mulit-modal distribution.

# %% [markdown]
# # 'euribor' variable

# %%
sns.FacetGrid(train, hue = "y", size = 5).map(sns.distplot, "euribor3m").add_legend();
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
sns.boxplot(x="y", y = "euribor3m", data = train)
sns.violinplot(x="y", y="euribor3m", data=train, size=6)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
#  Euribor mean for observations of 'yes' class is around 5 while that of 'no' class is close to 1.
#  However, a decent number of obervations have been recorded around 5 as well as 1 for both the classes.

# %% [markdown]
# # 'employees' variable

# %%
sns.FacetGrid(train, hue = "y", size = 5).map(sns.distplot, "nr.employed").add_legend();
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
sns.boxplot(x="y", y = "nr.employed", data = train)
sns.violinplot(x="y", y="nr.employed", data=train, size=6)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
#  The mean number of employees for 'no' class is close to 5200 while the mean number of emplyess for 'yes' class is around 5100.
#  Data is more evenly distributed for 'yes' with most observations recorded less than 5150.

# %%
sns.boxplot(data=train, orient="h");
# We notice that there is a huge disparity among the scale which requires us to bring all the variables to a comman scale.
# Out:
# <img src="data:image/png;base64,..." width="800">
